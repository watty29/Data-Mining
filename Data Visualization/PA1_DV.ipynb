# %% [markdown]
# ## Student Details
#
# When submitting, fill your name and ID in this cell. Note that this is a markdown cell.

# %% [markdown]
# # Programming Assignment 1:
# # Exploratory Analysis over census data for salaries from the year 1994

# %% [markdown]
# # Assignment Details
#
# In this assignment, you will conduct a guided exploration over census1994 Dataset. You will learn and use some of the most common exploration/aggregation/descriptive operations. This should also help you learn most of the key functionalities in Pandas.
#
# You will also learn how to use visualization libraries to identify patterns in data that will help in your further data analysis. You will also explore most popular chart types and how to use different libraries and styles to make your visualizations more attractive.

# %% [markdown]
# # Dataset Details
#
# In this assignment, you will work on census1994 dataset. This data was extracted from the census bureau database.
# Extraction was done by Barry Becker from the 1994 Census database. The objective of the survey was to determine whether a person makes over 50K a year or not.
#
# ### census 1994 Dataset
#
# ## >50K, <=50K.
# ## age: continuous.
# ## workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# ## fnlwgt: continuous.
# ## education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# ## education-num: continuous.
# ## marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# ## occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# ## relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# ## race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# ## gender: Female, Male.
# ## capital-gain: continuous.
# ## capital-loss: continuous.
# ## hours-per-week: continuous.
# ## native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# # Required Python Packages
# You will use the packages imported below in this assignment.
# You will not require any other packages.

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

#Array processing
import numpy as np
#Data analysis, wrangling and common exploratory operations
import pandas as pd
from pandas import Series, DataFrame

#For visualization. Matplotlib for basic viz and seaborn for more stylish figures
import matplotlib.pyplot as plt
# import seaborn as sns
import seaborn as sns
#For some of the date operations
#import datetime
import datetime

# %% [markdown]
# # Reading Dataset
# The Python code below reads the census1994 dataset into a Pandas data frame with the name df_census.
# For this code to work, the file 'census1994.csv' must be in the same folder as the notebook.

# %%
#read the csv file into a Pandas data frame
df_census = pd.read_csv('census1994.csv')

#return the first 5 rows of the dataset
df_census.head()
# Out:
#         Date  Age          WorkClass  fnlwgt   education  education-num  \
# 0  3/20/1994   39          State-gov   77516   Bachelors             13
# 1  1/14/1994   50   Self-emp-not-inc   83311   Bachelors             13
# 2  8/14/1994   38            Private  215646     HS-grad              9
# 3  3/17/1994   53            Private  234721        11th              7
# 4  9/20/1994   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# ...

# %% [markdown]
# # Task 1: Statistical Exploratory Data Analysis
# Let us start with getting know the dataset. Your first task will be to get some basic information by using Pandas features.

# %%
#For each task below, look for a Pandas function to do the task.
#Replace None in each task with your code.

#Before starting with the tasks in the assignment, we need to remove the rows with missing values
#write the code for it here and save the new data frame with the same name as df_census.
###################begin your code.
df_census = df_census[df_census['native-country']!=' ?']
print(df_census.shape)
# df_census = df_census.dropna(how='any',axis=0)
# print(df_census.head())
#checking for the Null entries
# null_columns=df_census.columns[df_census.isnull().any()]
# print(df_census[null_columns].isnull().sum())
###################end your code.


#Task 1-a: Print the details of the df_census data frame (information such as number of rows,columns, name of columns, etc)

print("Task 1-a: Details of df_census data frame are: \n")
df_census.info(verbose=None, buf=None, max_cols=None, memory_usage=None, null_counts=None)
#census1994.csv.info(verbose=None, buf=None, max_cols=None, memory_usage=None, null_counts=None)

#Task 1-b: Find the number of rows and columns in the df_census data frame.

print(df_census.shape)
num_rows = len(df_census.index)
num_cols = len(df_census.columns)
print("\n\nTask 1-b: Number of rows:%s and number of columns:%s" % (num_rows, num_cols)) 


#Task 1-c: Print the descriptive details (min, max, quartiles etc) for 'Age' column of the df_census
print("\n\nTask 1-c: Descriptive details of age is \n")
print(df_census['Age'].describe())

#Task 1-d: Print the number of unique values for 'education_num' and 'hours_per_week' columns
num_uniq_1 = df_census['education-num'].nunique(dropna=True)
num_uniq_2 = df_census['hours-per-week'].nunique(dropna=True)
print("\n\nTask 1-d: The number of unique 1### :", num_uniq_1)
print("Task 1-d: The number of unique 2### :", num_uniq_2)
# Out:
# (31978, 16)
# Task 1-a: Details of df_census data frame are:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31978 entries, 0 to 32560
# Data columns (total 16 columns):
# Date              31978 non-null object
# Age               31978 non-null int64
# WorkClass         31978 non-null object
# fnlwgt            31978 non-null int64
# education         31978 non-null object
# education-num     31978 non-null int64
# marital-status    31978 non-null object
# occupation        31978 non-null object
# relationship      31978 non-null object
# race              31978 non-null object
# gender            31978 non-null object
# capital-gain      31978 non-null int64
# capital-loss      31978 non-null int64
# hours-per-week    31978 non-null int64
# native-country    31978 non-null object
# class             31978 non-null object
# dtypes: int64(6), object(10)
# memory usage: 4.1+ MB
# (31978, 16)
#
#
# Task 1-b: Number of rows:31978 and number of columns:16
#
#
# ...

# %% [markdown]
# # Task 2: Aggregation & Filtering & Rank
# In this task, we will perform some very high level aggregation and filtering operations. Then, we will apply ranking on the results for some tasks. Pandas has a convenient and powerful syntax for aggregation, filtering, and ranking. DO NOT write a for loop. Pandas has built-in functions for all tasks.

# %%
#Task 2-a: Find out the sum of Captial Gain for people with education level as Bachelors and HS-Grad.
sum_capital_gain_bachelors = df_census.loc[df_census['education'].str.contains('Bachelors'), 'capital-gain'].sum()
sum_capital_gain_HS_Grad = df_census.loc[df_census['education'].str.contains('HS-Grad'), 'capital-gain'].sum()
# dfb = df_census[df_census['education'].str.contains('Bachelors')]
# sum_capital_gain_bachelors = sum(dfb['capital-gain'])
# dfhs = df_census[df_census['education'].str.contains('HS-Grad')]
# sum_capital_gain_HS_Grad = sum(dfhs['capital-gain'])
print ("Task 2-a: The sum of capital gain for education level as bachelors is %s and as HS-Grad is %s" 
       % (sum_capital_gain_bachelors, sum_capital_gain_HS_Grad))


#Task 2-b: Find out the total number of people surveyed in months may, october and december.
#Create a new column for 'Survey_Month' by using 'Date' column
#write the code for extracting the month from the date column here

###############begin your code here
df_census['Date'] = pd.to_datetime(df_census['Date'])
df_census['Survey_Month'] = df_census['Date'].apply(lambda x: x.month)
print(df_census[['Survey_Month']].head())
###############send you code here

####

####
num_surveys_may = len(df_census.query("Survey_Month == 5"))
num_surveys_october = len(df_census.query("Survey_Month == 10"))
num_surveys_december = len(df_census.query("Survey_Month == 12"))
print ("\n\nTask 2-b: The total number of surveys in may is %s, in october is %s, and in december is %s" 
       % (num_surveys_may, num_surveys_october, num_surveys_december))


#Task 2-c: Let us now use multiple filtering criteria
# Find out the total number of surveys in september and november with workclass as private and age less than 50.
num_surveys_september = len(df_census[(df_census['WorkClass'].str.contains('Private')) & (df_census.Age < 50) & (df_census.Survey_Month == 9)])
num_surveys_november = len(df_census[(df_census['WorkClass'].str.contains('Private')) & (df_census.Age < 50) & (df_census.Survey_Month == 11)])
print ("\n\nTask 2-c: The total number of surveys that meet the given conditions in september is %s and in november is %s" 
       % (num_surveys_september, num_surveys_november))


#Task 2-d: Find out 3 least surveyed education categories, print their names and corresponding number of surveys for periods January-June and July-December.
top3_least_surveyed_Jan_June = df_census[(df_census.Survey_Month >= 1) & (df_census.Survey_Month <= 6)].education.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True).nsmallest(n=3)
top3_least_surveyed_July_December = df_census[(df_census.Survey_Month >= 7) & (df_census.Survey_Month <= 12)].education.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True).nsmallest(n=3)
print ("\n\nTask 2-d: \nThe top 3 least surveyed education categories in January-June: \n%s \n\nThe top 3 least surveyed education categories in July-December: \n%s" 
                     % (top3_least_surveyed_Jan_June,top3_least_surveyed_July_December))


#Task 2-e: Find out top 5 native-countries besides United-States, print their names and number of surveys belonging to each.
top5_most_surveyed_native_countries = df_census.groupby('native-country').agg('count')['Survey_Month'].nlargest(n=6)
j=pd.DataFrame(top5_most_surveyed_native_countries)
s=j[j['Survey_Month']!=29170]
print ("\n\nTask 2-e: \nThe top 5 most surveyed native countries : \n%s" 
                     % (s))


#Task 2-f: Find out Top-5 native-countries with the most number of samples belonging to class >50K
top5_native_countries = df_census[df_census['class'].str.contains('>50K')].groupby('native-country').agg('count')['Survey_Month'].nlargest(n=5)
print ("\n\nTask 2-f: \nThe top 5 native countries with the most number of surveys with class >50K: \n%s" 
                     % (top5_native_countries))
# print(df_census.columns)
# Out:
# Task 2-a: The sum of capital gain for education level as bachelors is 8992792 and as HS-Grad is 0
#    Survey_Month
# 0             3
# 1             1
# 2             8
# 3             3
# 4             9
#
#
# Task 2-b: The total number of surveys in may is 2683, in october is 2670, and in december is 2775
#
#
# Task 2-c: The total number of surveys that meet the given conditions in september is 1465 and in november is 1507
#
#
# Task 2-d:
# The top 3 least surveyed education categories in January-June:
#  Preschool     20
#  1st-4th       78
#  5th-6th      173
# Name: education, dtype: int64
#
# The top 3 least surveyed education categories in July-December:
#  Preschool     30
#  1st-4th       85
#  5th-6th      145
# Name: education, dtype: int64
#
#
# Task 2-e:
# The top 5 most surveyed native countries :
#                 Survey_Month
# native-country
#  Mexico                  643
#  Philippines             198
#  Germany                 137
#  Canada                  121
# ...

# %% [markdown]
# # Task 3: Visualization
# In this task, you will perform a number of visualization tasks to get some intuition about the data. Visualization is a key component of exploration. You can choose to use either Matplotlib or Seaborn for plotting. The default figures generated from Matplotlib might look a bit ugly. So you might want to try Seaborn to get better figures. Seaborn has a variety of styles. Feel free to experiment with them and choose the one you like. We have earmarked 10 points for the aesthetics of your visualizations.

# %%
# %matplotlib inline
sns.set_style('whitegrid')
sns.set(font_scale = 1.3)
plt.rcParams['font.family'] = "georgia"

#Task 3-a: Draw a histogram for total number of surveys taken each month. Dislpay months with their corresponding numbers(Eg: January is 1) 
#########################begin code for Task 3-a
df=df_census.Survey_Month.value_counts(normalize=False, sort=False, ascending=False, bins=None, dropna=True)
# df=df_census.groupby('Survey_Month').agg('count')['Survey_Month']
# df.reset_index(name='month_count')
# print(df[1])
p=pd.DataFrame(df)
# print(p.index)
# print(p['Survey_Month'])
# print(type(df))
# print(df)
plt.figure(figsize=(16,8))
al = sns.color_palette("Greens_d", len(df))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid") 
b=sns.barplot(x=p.index,y=p['Survey_Month'],palette=al)
plt.title("No. of surveys taken each month") # sets the title
plt.xlabel("Month") # sets X axis label
plt.ylabel("No.of surveys")# sets Y axis label
plt.yticks(np.arange(0,5000, step=1000))
# plt.ylim(0,17000,100) # limit is set for Y axis i.e from 0 to 17000 with 100 as minimum
b.set_xticklabels(('January 1', 'Febuary 2', 'March 3', 'April 4', 'May 5','June 6','July 7','August 8','September 9','October 10','November 11','December 12'),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-a


#Task 3-b: Draw a vertical bar chart for total number of surveys taken for each gender for each month. Display months with their corresponding names.
# Remember to make the bar chart into a vertical bar chart
#########################begin code for Task 3-b

with sns.axes_style('white'):
    g = sns.catplot("Survey_Month", data=df_census, aspect=4.0, kind='count',
                       hue='gender', order=range(1, 13))
    g.set_ylabels('Number of Surveys')
    g.set_xticklabels(('January 1', 'Febuary 2', 'March 3', 'April 4', 'May 5','June 6','July 7','August 8','September 9','October 10','November 11','December 12'),rotation=90)
plt.title("total number of surveys taken for each gender for each month")
plt.show()

#########################end code for Task 3-b

#Task 3-c: Draw a horizontal bar chart for number of surveys taken with respect to age feature keeping the age interval as 15.
# Remember to make the bar chart into a horizontal bar chart
#########################begin code for Task 3-c(Not working)
# with sns.axes_style('white'):
#     g = sns.catplot(y= p['Survey_Month'],x= df_census["Age"], data=df_census,aspect=4.0, kind='bar')
#     g.set_ylabels('Number of Surveys')
# #     g.set_xticklabels(('January 1', 'Febuary 2', 'March 3', 'April 4', 'May 5','June 6','July 7','August 8','September 9','October 10','November 11','December 12'),rotation=90)
# plt.title("total number of surveys taken for each gender for each month")
# plt.show()
# plt.figure(figsize=(16,8))
# al = sns.color_palette("Greens_d", len(df_census))
# sns.set_style("ticks",{"xtick.major.size":8,
# "ytick.major.size":8})
# sns.axes_style("whitegrid")
# s=sns.barplot(x=df_census["Survey_Month"].count(),y=df_census["Age"], data=df_census)  
# plt.title("Age vs Hours per week") # sets the title
# plt.xlabel("Age") # sets X axis label
# plt.ylabel("hours-per-week")# sets Y axis label
# # plt.yticks(np.arange(0,150, step=10))
# # s.set_xticklabels(s.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
# plt.show()
#########################end code for Task 3-c


#Task 3-d: Draw a "vertical" bar chart that lists the top-5 native-countries based on the number of samples with class >50K.
# Remember to make the bar chart into a vertical bar chart
#########################begin code for Task 3-d
p2=pd.DataFrame(top5_native_countries)
plt.figure(figsize=(16,8))
al = sns.color_palette("Greens_d", len(top5_native_countries))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid") 
b=sns.barplot(x=p2.index,y=p2['Survey_Month'],palette=al)
plt.title("top-5 native-countries based on the number of samples with class >50K") # sets the title
plt.xlabel("native-countries") # sets X axis label
plt.ylabel("No.of samples")# sets Y axis label
plt.yticks(np.arange(0,10000, step=1000))
# plt.ylim(0,17000,100) # limit is set for Y axis i.e from 0 to 17000 with 100 as minimum
b.set_xticklabels(b.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-d


#Task 3-e: Now repeat Task 3-d based on education (again top-5)
#########################begin code for Task 3-e
top5_education = df_census[df_census['class'].str.contains('>50K')].groupby('education').agg('count')['Survey_Month'].nlargest(n=5)
p3=pd.DataFrame(top5_education)
plt.figure(figsize=(16,8))
al = sns.color_palette("Greens_d", len(top5_education))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid") 
b=sns.barplot(x=p3.index,y=p3['Survey_Month'])
plt.title("top-5 education based on the number of samples with class >50K") # sets the title
plt.xlabel("education") # sets X axis label
plt.ylabel("No.of samples")# sets Y axis label
plt.yticks(np.arange(0,4500, step=500))
# plt.ylim(0,17000,100) # limit is set for Y axis i.e from 0 to 17000 with 100 as minimum
b.set_xticklabels(b.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-e


#Task 3-f: Draw a scatter plot for age vs hours per week.
#########################begin code for Task 3-f
plt.figure(figsize=(16,8))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid")
s=sns.scatterplot(x=df_census["Age"], y=df_census["hours-per-week"], data=df_census, palette = "rocket_r")
plt.title("Age vs Hours per week") # sets the title
plt.xlabel("Age") # sets X axis label
plt.ylabel("hours-per-week")# sets Y axis label
# plt.yticks(np.arange(0,150, step=10))
# s.set_xticklabels(s.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-f


#Task 3-g: Draw a line chart showing average capital gain for each education category.
# X-axis : education category, Y-axis : the avg capital gain
#########################begin code for Task 3-g
plt.figure(figsize=(16,8))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid")
s=sns.lineplot(x=df_census["education"], y=df_census["capital-gain"].mean(), data=df_census)
plt.title("average capital gain for each education category") # sets the title
plt.xlabel("Education") # sets X axis label
plt.ylabel("average capital-gain")# sets Y axis label
# plt.yticks(np.arange(0,150, step=10))
# s.set_xticklabels(s.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-g


#Task 3-h: Draw a 'horizontal' bar chart for the top-5 most common occupation. 
#########################begin code for Task 3-h
top5_most_common_occupation = df_census.occupation.value_counts(normalize=False, sort=False, ascending=False, bins=None, dropna=True).nlargest(n=5)
# print(top5_most_common_occupation)
p4=pd.DataFrame(top5_most_common_occupation)
# print(p4)
plt.figure(figsize=(16,8))
al = sns.color_palette("Greens_d", len(top5_most_common_occupation))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid") 
b=sns.barplot(x=p4['occupation'],y=p4.index,palette=al)
plt.title("top-5 most common occupation") # sets the title
plt.xlabel("Frequency") # sets X axis label
plt.ylabel("occupation")# sets Y axis label
# plt.yticks(np.arange(0,5000, step=1000))
# plt.ylim(0,17000,100) # limit is set for Y axis i.e from 0 to 17000 with 100 as minimum
# b.set_xticklabels(b.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-h


#Task 3-i: Draw a 'horizontal' bar chart for the top-5 most common workclass. 
#########################begin code for Task 3-i
top5_most_common_workclass = df_census.WorkClass.value_counts(normalize=False, sort=False, ascending=False, bins=None, dropna=True).nlargest(n=5)
# print(top5_most_common_workclass)
p5=pd.DataFrame(top5_most_common_workclass)
# print(p5)
plt.figure(figsize=(16,8))
al = sns.color_palette("Greens_d", len(top5_most_common_workclass))
sns.set_style("ticks",{"xtick.major.size":8,
"ytick.major.size":8})
sns.axes_style("whitegrid") 
b=sns.barplot(x=p5['WorkClass'],y=p5.index,palette=al)
plt.title("top-5 most common WorkClass") # sets the title
plt.xlabel("Frequency") # sets X axis label
plt.ylabel("WorkClass")# sets Y axis label
# plt.yticks(np.arange(0,5000, step=1000))
# plt.ylim(0,17000,100) # limit is set for Y axis i.e from 0 to 17000 with 100 as minimum
# b.set_xticklabels(b.get_xticklabels(),rotation=90) # Rotated the X axis labels to increase visual appeal
plt.show()
#########################end code for Task 3-i

# %% [markdown]
# # Task 4:
# Find out an interesting information from your census1994 dataset. Create a visualization for it.
# This task is worth 20 points. Your result will be judged based on the uniqueness and quality of your work (having a meaningful result and an aesthetic visulization).

# %%
#########################begin code for Task 4

with sns.axes_style('white'):
    g = sns.catplot("Survey_Month", data=df_census, aspect=4.0, kind='count',
                       hue='class', order=range(1, 13))
    g.set_ylabels('Number of Surveys')
#     g.set_xticklabels(('January 1', 'Febuary 2', 'March 3', 'April 4', 'May 5','June 6','July 7','August 8','September 9','October 10','November 11','December 12'),rotation=90)
plt.title("total number of surveys taken for each class for each month")
plt.show()


######################################
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

#Read in data & create total column
df_census["total"] = df_census.Age + df_census['hours-per-week']

#Set general plot properties
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})

#Plot 1 - background - "total" (top) series
sns.barplot(x = df_census['class'], y = df_census.total, color = "red")

#Plot 2 - overlay - "bottom" series
bottom_plot = sns.barplot(x = df_census['class'], y = df_census.Age, color = "#0000A3")


topbar = plt.Rectangle((0,0),1,1,fc="red", edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc='#0000A3',  edgecolor = 'none')
l = plt.legend([bottombar, topbar], ['Age <40', 'Age >=40'], loc=1, ncol = 2, prop={'size':16})
l.draw_frame(False)

#Optional code - Make plot look nicer
sns.despine(left=True)
bottom_plot.set_ylabel("Age")
bottom_plot.set_xlabel("class")

#Set fonts to consistent 16pt size
for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
             bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
    item.set_fontsize(16)
#########################end code for Task 4

# %% [markdown]
# 1) The visualization for each month is quite constant for both classes, though the individuals making over $50,000 have significantly less number of surveys then the individuals maling less than $50,000. The factor for more number of surveys by individuals making less than $ 50,000 can be vast one of be like  getting benefits from government for taking up of surveys.
# #############################################################################################################################
#
# #############################################################################################################################
# 2)The percentage of individuals working less than 40 hours per week making less than $50,000 drastically decreases as age increases, and making over $50,000 increases significantly with age when individual works greater than 40 hours per week.

# %% [markdown]
# # Grading
#
# Task 1: 10 points
# Task 2: 30 points
# Task 3: 40 points
# Task 4: 20 points
